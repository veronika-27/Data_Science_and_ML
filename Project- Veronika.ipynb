# %% [markdown]
# Assignment 4
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to Preview the Grading for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find at least two datasets on the web which are related, and that you visualize these datasets to answer a question __with the broad topic of economic activity or measures (see below) for the region of Ann Arbor, Michigan, United States, or United States more broadly.__
#
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare Ann Arbor, Michigan, United States to Ann Arbor, USA. In that case at least one source file must be about Ann Arbor, Michigan, United States.
#
# You are welcome to choose datasets at your discretion, but keep in mind they will be shared with your peers, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
# State the region and the domain category that your data sets are about (e.g., Ann Arbor, Michigan, United States and economic activity or measures).
# You must state a question about the domain category and region that you identified as being interesting.
# You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
# You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
# You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
# What do we mean by economic activity or measures? For this category you might look at the inputs or outputs to the given economy, or major changes in the economy compared to other regions.
#
# Tips
# Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# Several international agencies, such as the United Nations, the World Bank, the Global Open Data Index are other great places to look for data.
# This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
# Example
# Looking for an example? Here's what our course assistant put together for the Ann Arbor, MI, USA area using sports and athletics as the topic. Example Solution File

# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
ann_data=pd.read_csv(r'Employment by Industries.csv')

# %%
ann_data.drop(columns=['ID Group', 'Group','ID Industry', 'ID Year', 'ID State','State','ID Geography', 'Slug Geography'], 
             inplace=True)

# %%
ann_data.set_index('Year', inplace=True)

# %%
ann_data.drop(index=[2018, 2017,2014, 2013, 2015], inplace=True)

# %%
ann_data.head(20)
# Out:
#                                                Industry  \
# Year
# 2016           Agriculture, Forestry, Fishing & Hunting
# 2016          Mining, Quarrying, & Oil & Gas Extraction
# 2016                                       Construction
# 2016                                      Manufacturing
# 2016                                    Wholesale Trade
# 2016                                       Retail Trade
# 2016                       Transportation & Warehousing
# 2016                                          Utilities
# 2016                                        Information
# 2016                                Finance & Insurance
# 2016                     Real Estate & Rental & Leasing
# 2016     Professional, Scientific, & Technical Services
# 2016              Management of Companies & Enterprises
# 2016  Administrative & Support & Waste Management Se...
# 2016                               Educational Services
# 2016                    Health Care & Social Assistance
# ...

# %%
ann_data['Industry'].values
# Out:
# array(['Agriculture, Forestry, Fishing & Hunting',
#        'Mining, Quarrying, & Oil & Gas Extraction', 'Construction',
#        'Manufacturing', 'Wholesale Trade', 'Retail Trade',
#        'Transportation & Warehousing', 'Utilities', 'Information',
#        'Finance & Insurance', 'Real Estate & Rental & Leasing',
#        'Professional, Scientific, & Technical Services',
#        'Management of Companies & Enterprises',
#        'Administrative & Support & Waste Management Services',
#        'Educational Services', 'Health Care & Social Assistance',
#        'Arts, Entertainment, & Recreation',
#        'Accommodation & Food Services',
#        'Other Services, Except Public Administration',
#        'Public Administration'], dtype=object)

# %%
ann_data.rename(columns={'Workforce by Industry and Gender': 'Workforce','Workforce by Industry and Gender Moe':'MoE'}, inplace=True)

# %%
ann_data['Workforce'].sum()
# Out:
# 59674

# %%
ann_data['Proportions (%)']= ann_data['Workforce']/ann_data['Workforce'].sum()*100

# %%
ann_data.drop(columns=['Geography','MoE'], inplace=True)

# %%
ann_data.sort_values(by=['Proportions (%)'], ascending=False)
# Out:
#                                                Industry  Workforce  \
# Year
# 2016                               Educational Services      20110
# 2016                    Health Care & Social Assistance       9221
# 2016     Professional, Scientific, & Technical Services       6005
# 2016                                      Manufacturing       4786
# 2016                      Accommodation & Food Services       4716
# 2016                                       Retail Trade       3841
# 2016       Other Services, Except Public Administration       1887
# 2016                                        Information       1428
# 2016                                Finance & Insurance       1148
# 2016                  Arts, Entertainment, & Recreation       1115
# 2016                                       Construction        972
# 2016  Administrative & Support & Waste Management Se...        953
# 2016                              Public Administration        908
# ...

# %%
pet_data=pd.read_csv('CensusProfile2016.csv',encoding='cp863', skiprows=[0,2])

# %%
pet_data.head()
# Out:
#                       Topic                                Characteristics  \
# 0  Population and dwellings                               Population; 2016
# 1  Population and dwellings                               Population; 2011
# 2  Population and dwellings     Population percentage change; 2011 to 2016
# 3  Population and dwellings                        Total private dwellings
# 4  Population and dwellings  Private dwellings occupied by usual residents
#
#    Note    Total  Male  Female   Total.1  Male.1  Female.1
# 0   1.0  81032.0   NaN     NaN  138236.0     NaN       NaN
# 1   1.0  78777.0   NaN     NaN  134928.0     NaN       NaN
# 2   NaN      2.9   NaN     NaN       2.5     NaN       NaN
# 3   2.0  36785.0   NaN     NaN   70551.0     NaN       NaN
# 4   3.0  34710.0   NaN     NaN   57743.0     NaN       NaN

# %%
pet_data.set_index('Topic', inplace=True)

# %%
pet_new=pet_data.iloc[1896:1919, :]
pet_new.head()
# Out:
#                                                                                       Characteristics  \
# Topic
# Industry - North American Industry Classificati...  Total labour force population aged 15 years an...
# Industry - North American Industry Classificati...              Industry - NAICS2012 - not applicable
# Industry - North American Industry Classificati...                            All industry categories
# Industry - North American Industry Classificati...      11 Agriculture; forestry; fishing and hunting
# Industry - North American Industry Classificati...      21 Mining; quarrying; and oil and gas extr...
#
#                                                      Note    Total     Male  \
# Topic
# Industry - North American Industry Classificati...  173.0  39560.0  19455.0
# Industry - North American Industry Classificati...  169.0   1110.0    560.0
# Industry - North American Industry Classificati...  170.0  38450.0  18900.0
# ...

# %%
pet_new.reset_index(inplace=True)

# %%
pet_new.columns
# Out:
# Index(['Topic', 'Characteristics', 'Note', 'Total', 'Male', 'Female',
#        'Total.1', 'Male.1', 'Female.1'],
#       dtype='object')

# %%
pet_nn=pet_new.drop(columns=['Topic','Note', 'Male', 'Female', 'Total.1', 'Male.1', 'Female.1'])

# %%
pet_nn.head()
# Out:
#                                      Characteristics    Total
# 0  Total labour force population aged 15 years an...  39560.0
# 1              Industry - NAICS2012 - not applicable   1110.0
# 2                            All industry categories  38450.0
# 3      11 Agriculture; forestry; fishing and hunting    245.0
# 4      21 Mining; quarrying; and oil and gas extr...    135.0

# %%
pet_n=pet_nn.iloc[3:, :]
pet_n.head()
# Out:
#                                      Characteristics   Total
# 3      11 Agriculture; forestry; fishing and hunting   245.0
# 4      21 Mining; quarrying; and oil and gas extr...   135.0
# 5                                       22 Utilities   360.0
# 6                                    23 Construction  2355.0
# 7                                31-33 Manufacturing  2730.0

# %%
pet_n['Total'].sum()
# Out:
# 38445.0

# %%
type(pet_n['Total'].sum())
# Out:
# numpy.float64

# %%
pet_n['Proportions (%)']= pet_n['Total']/pet_n['Total'].sum()*100
# Out:
# <ipython-input-25-7666ddb44b7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_n['Proportions (%)']= pet_n['Total']/pet_n['Total'].sum()*100

# %%
pet_n.rename(columns={'Characteristics':'Industry', 'Total':'Workforce'}, inplace=True)
# Out:
# c:\users\vk_27\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
pet_n.sort_values(by='Proportions (%)', ascending=False)
# Out:
#                                              Industry  Workforce  \
# 18               62 Health care and social assistance     5875.0
# 9                                  44-45 Retail trade     5410.0
# 17                            61 Educational services     3805.0
# 20                 72 Accommodation and food services     3475.0
# 7                                 31-33 Manufacturing     2730.0
# 16      56 Administrative and support; waste manag...     2535.0
# 6                                     23 Construction     2355.0
# 22                           91 Public administration     2095.0
# 14      54 Professional; scientific and technical ...     1910.0
# 21      81 Other services (except public administr...     1710.0
# 10               48-49 Transportation and warehousing     1385.0
# 19              71 Arts; entertainment and recreation     1055.0
# 8                                  41 Wholesale trade     1030.0
# ...

# %%
# Importing re package for using regular expressions
import re
  
# Function to clean the names
def Clean_ind(Industry_name):
    # Search for digit in the ind. name followed by space
    
    if re.search('[0-9]\s', Industry_name):
  
        # Extract the position of the end of pattern
        pos = re.search('[0-9]\s', Industry_name).end()
  
        # return the cleaned name
        return Industry_name[pos:]
  
    else:
        # if clean up needed return the same name
        return Industry_name
          
# Updated the industry columns
pet_n['Industry'] = pet_n['Industry'].apply(Clean_ind)
  
# Print the updated dataframe
pet_n
# Out:
# <ipython-input-28-150f76ef680a>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_n['Industry'] = pet_n['Industry'].apply(Clean_ind)
#                                              Industry  Workforce  \
# 3          Agriculture; forestry; fishing and hunting      245.0
# 4       Mining; quarrying; and oil and gas extraction      135.0
# 5                                           Utilities      360.0
# 6                                        Construction     2355.0
# 7                                       Manufacturing     2730.0
# 8                                     Wholesale trade     1030.0
# 9                                        Retail trade     5410.0
# 10                     Transportation and warehousing     1385.0
# ...

# %%
pet_n['Industry']=pet_n['Industry'].str.title()
# Out:
# <ipython-input-29-4babfd1fd64e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_n['Industry']=pet_n['Industry'].str.title()

# %%
pet_n['Industry']=pet_n['Industry'].str.replace(';' , ',')
# Out:
# <ipython-input-30-198bbac2c099>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_n['Industry']=pet_n['Industry'].str.replace(';' , ',')

# %%
pet_n['Industry']=pet_n['Industry'].str.replace('And' , '&')
# Out:
# <ipython-input-31-268905edf2d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_n['Industry']=pet_n['Industry'].str.replace('And' , '&')

# %%
pet_n['Industry']=pet_n['Industry'].str.replace('(', ',')
pet_n['Industry']=pet_n['Industry'].str.replace(')' , '')
# Out:
# <ipython-input-32-3b52f6aaaeb5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_n['Industry']=pet_n['Industry'].str.replace('(', ',')
# <ipython-input-32-3b52f6aaaeb5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pet_n['Industry']=pet_n['Industry'].str.replace(')' , '')

# %%
pet_n['Industry'].values
# Out:
# array(['Agriculture, Forestry, Fishing & Hunting',
#        'Mining, Quarrying, & Oil & Gas Extraction', 'Utilities',
#        'Construction', 'Manufacturing', 'Wholesale Trade', 'Retail Trade',
#        'Transportation & Warehousing',
#        'Information & Cultural Industries', 'Finance & Insurance',
#        'Real Estate & Rental & Leasing',
#        'Professional, Scientific & Technical Services',
#        'Management Of Companies & Enterprises',
#        'Administrative & Support, Waste Management & Remediation Services',
#        'Educational Services', 'Health Care & Social Assistance',
#        'Arts, Entertainment & Recreation',
#        'Accommodation & Food Services',
#        'Other Services ,Except Public Administration',
#        'Public Administration'], dtype=object)

# %%
ann_data['Industry'].count()
# Out:
# 20

# %%
pet_n.replace({"Other Services ,Except Public Administration" : "Other Services, Except Public Administration",
              'Administrative & Support, Waste Management & Remediation Services':'Administrative & Support & Waste Management Services', 
               'Arts, Entertainment & Recreation':'Arts, Entertainment, & Recreation', 'Administrative & Support, Waste Management & Remediation Services':'Administrative & Support & Waste Management Services',
              'Professional, Scientific & Technical Services':'Professional, Scientific, & Technical Services', 'Information & Cultural Industries': 'Information', 
              'Management Of Companies & Enterprises': 'Management of Companies & Enterprises'}, inplace=True)
# Out:
# c:\users\vk_27\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4383: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df_comp = pd.merge(ann_data, pet_n, on='Industry', how='inner')
df_comp.rename(columns={'Proportions (%)_x':'Ann_Arbor', 'Proportions (%)_y': 'Peterborough'}, inplace=True)

# %%
df_comp.drop(columns={'Workforce_x',  'Workforce_y'}, inplace=True)

# %%
df_comp=df_comp.sort_values(['Ann_Arbor', 'Peterborough'], ascending=False)
df_comp.set_index('Industry')
# Out:
#                                                     Ann_Arbor  Peterborough
# Industry
# Educational Services                                33.699769      9.897256
# Health Care & Social Assistance                     15.452291     15.281571
# Professional, Scientific, & Technical Services      10.063009      4.968136
# Manufacturing                                        8.020243      7.101053
# Accommodation & Food Services                        7.902939      9.038887
# Retail Trade                                         6.436639     14.072051
# Other Services, Except Public Administration         3.162181      4.447913
# Information                                          2.393002      2.015867
# Finance & Insurance                                  1.923786      2.653141
# Arts, Entertainment, & Recreation                    1.868485      2.744180
# Construction                                         1.628850      6.125634
# ...

# %%
import matplotlib.pyplot as plt

x = df_comp['Industry'].values
Ann_Arrbor = df_comp['Ann_Arbor'].values
Peterborough=df_comp['Peterborough'].values

fig, axs = plt.subplots(1,2, figsize=(10,4), sharey=True, sharex=True)
axs[0].barh(x,Ann_Arrbor,  label='Ann_Arbor')
axs[1].barh(x, Peterborough,color='darkorange', label= 'Peterborough')
axs[0].legend()
axs[1].legend()
ax=df_comp.plot.bar(x='Industry',figsize=(12,4))
plt.ylabel('Share of industries (%)')

fig.suptitle('Employment by Industries (2016)', alpha=0.8)
# Out:
# Text(0.5, 0.98, 'Employment by Industries (2016)')
